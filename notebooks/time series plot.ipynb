# %%
import sys
sys.path.insert(0,'..')

from sktime_analysis import *
import matplotlib.pyplot as plt

# %%
X, y = create_data_for_sktime(1)

fig, ax = plt.subplots(dpi=500)
    
for i, series in enumerate(X['x_1']):
    if i%9 == 0:
        series[0:200].plot(ax=ax, legend=True)
ax.set_title("Node 1's Motion")
ax.set_xlabel("time step")
ax.set_ylabel("Horizontal Displacement from Equilibrium")
ax.legend(["Network 1", "Network 2"]);
