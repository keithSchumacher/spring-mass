# %%
import sys
sys.path.insert(0,'..')
from network_animate import *
network_animate(quality='youtube')

# %% [markdown]
# Two networks of 9 vertices and 20 edges each.
#
# The first half of video shows the network to which each vertex belongs. The networks/vertices/edges are color coded either red or blue.
#
# Next, the vibrating vertices without edges and color coding are shown.
#
# Near the end of the video, the vibrating vertices without vizualization offsets are shown. This is the data that we attempt to classify as belonging to a particular network. Only the 2-D displacement from a vertex's equillibrium point is known.
#
# https://youtu.be/zu7gIVKmhYw
